# %%
# !apt-get install -y -qq software-properties-common python-software-properties module-init-tools
# !add-apt-repository -y ppa:alessandro-strada/ppa 2>&1 > /dev/null
# !apt-get update -qq 2>&1 > /dev/null
# !apt-get -y install -qq google-drive-ocamlfuse fuse
from google.colab import auth
auth.authenticate_user()
from oauth2client.client import GoogleCredentials
creds = GoogleCredentials.get_application_default()
import getpass
# !google-drive-ocamlfuse -headless -id={creds.client_id} -secret={creds.client_secret} < /dev/null 2>&1 | grep URL
vcode = getpass.getpass()
# !echo {vcode} | google-drive-ocamlfuse -headless -id={creds.client_id} -secret={creds.client_secret}

# %%
# !mkdir -p drive
# !google-drive-ocamlfuse drive

# %%
# !pip3 install hyperchamber pillow
# !python3 -m pip install -U pygame --user
# Out:
# ...
# done
#   Stored in directory: /content/.cache/pip/wheels/73/01/7a/f71ba9097cfcb72196fa2faaca6435d5bded0fad8c10dfcf30
# Successfully built hyperchamber
# ...
#     100% |████████████████████████████████| 9.4MB 4.1MB/s
# ...

# %%
# !python3 -m pip install -U pygame --user
# Out:
# Requirement already up-to-date: pygame in ./.local/lib/python3.6/site-packages (1.9.3)

# %%
# !ls
# Out:
# datalab  drive	hypergan  samples  saves

# %%
# %cd /content/drive/Hyper_GAN
# Out:
# /content/drive/Hyper_GAN

# %%
# !mkdir Hyper_GAN

# %%
# !ls
# Out:
# communication Diagram.html  Inpainting		  sentiment
# Diagrams_		    keras-mnist-tutorial  Untitled0.ipynb
# GP			    NLP			  Widebot
# Hyper_GAN		    Report.docx.odt

# %%
# !apt-get install python-virtualenv
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following additional packages will be installed:
#   python-pip-whl python-pkg-resources python3-pkg-resources python3-virtualenv
#   virtualenv
# Suggested packages:
#   python-setuptools python3-setuptools
# The following NEW packages will be installed:
#   python-pip-whl python-pkg-resources python-virtualenv python3-pkg-resources
#   python3-virtualenv virtualenv
# 0 upgraded, 6 newly installed, 0 to remove and 24 not upgraded.
# Need to get 1,700 kB of archives.
# After this operation, 3,034 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu artful/universe amd64 python-pip-whl all 9.0.1-2 [1,379 kB]
# Get:2 http://archive.ubuntu.com/ubuntu artful/main amd64 python-pkg-resources all 36.2.7-2 [128 kB]
# Get:3 http://archive.ubuntu.com/ubuntu artful/universe amd64 python-virtualenv all 15.1.0+ds-1 [46.6 kB]
# ...

# %%
# !virtualenv --system-site-packages -p python3 hypergan
# !source hypergan/bin/activate
# Out:
# Already using interpreter /usr/bin/python3
# Using base prefix '/usr'
# New python executable in /content/drive/Hyper_GAN/hypergan/bin/python3
# Also creating executable in /content/drive/Hyper_GAN/hypergan/bin/python
# Installing setuptools, pkg_resources, pip, wheel...done.
# /bin/sh: 1: source: not found

# %%
# !hypergan new drive/GP/Hyper_GAN/GAN_GP
# Out:
# /bin/sh: 1: hypergan: not found

# %%
# !hypergan train drive/GP/Hyper_GAN/dataset/apple -s 224x224x3 -f png -c drive/GP/Hyper_GAN/GAN_GP --steps 10000 --noviewer --sampler static_batch  --sample_every 100 --save_samples --save_every 500
# Out:
# /bin/sh: 1: hypergan: not found

# %%
# !rsync -avz --delete "/content/saves" "/content/drive/GP/Hyper_GAN/saves/"
# Out:
# sending incremental file list
# rsync: link_stat "/content/saves" failed: No such file or directory (2)
# rsync: mkdir "/content/drive/GP/Hyper_GAN/saves" failed: No such file or directory (2)
# rsync error: error in file IO (code 11) at main.c(675) [Receiver=3.1.2]

# %%
# !rsync -avz --delete "/content/samples" "/content/drive/GP/Hyper_GAN/samples"
# Out:
# sending incremental file list
# rsync: link_stat "/content/samples" failed: No such file or directory (2)
# rsync: change_dir#3 "/content/drive/GP/Hyper_GAN" failed: No such file or directory (2)
# rsync error: errors selecting input/output files, dirs (code 3) at main.c(713) [Receiver=3.1.2]

# %%
 # !hypergan -h
# Out:
# /bin/sh: 1: hypergan: not found

# %%
# !hypergan new mymodel -l
# Out:
# /bin/sh: 1: hypergan: not found
